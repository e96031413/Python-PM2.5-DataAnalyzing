# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']  
mpl.rcParams['axes.unicode_minus'] = False

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 5 columns):
# SiteName     77 non-null object
# County       77 non-null object
# AQI          77 non-null int64
# PM2.5        77 non-null int64
# WindSpeed    77 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.1+ KB
#               AQI      PM2.5  WindSpeed
# count   77.000000  77.000000  77.000000
# mean    62.636364  21.246753   2.598701
# std     23.594663  11.093094   1.925692
# min     28.000000   0.000000   0.000000
# 25%     47.000000  13.000000   1.200000
# 50%     54.000000  18.000000   2.200000
# 75%     74.000000  28.000000   3.500000
# max    115.000000  48.000000   9.800000

# %%
df=pd.read_excel('C:/Users/Yanwei/Desktop/1129-0900.xlsx') #2018/11/29日早上9點00分的資料
df.plot()

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, vars=['PM2.5', 'AQI','WindSpeed'])

# %%
df.corr()
# Out:
#                 AQI     PM2.5  WindSpeed
# AQI        1.000000  0.953893  -0.165918
# PM2.5      0.953893  1.000000  -0.259362
# WindSpeed -0.165918 -0.259362   1.000000

# %%
pic=df.plot(kind = 'scatter', x = 'WindSpeed', y = 'PM2.5', title = '風速與PM2.5之關係') #風速越小，PM2.5指數越高

# %%
pic=df.plot(kind = 'scatter', x = 'WindSpeed', y = 'AQI', title = '風速與AQI之關係')

# %%
pic=df.plot(kind = 'scatter', x = 'PM2.5', y = 'AQI', title = 'PM2.5指數與AQI之關係') #PM2.5指數與AQI似乎出現正相關

# %%
df.plot(kind='kde')

# %%
plt.scatter(df['WindSpeed'],df['PM2.5'],color='red')
plt.scatter(df['WindSpeed'],df['AQI'],color='blue')
plt.show()

# %%
plt.scatter(df['WindSpeed'],df['PM2.5'],color='red')

# %%
plt.scatter(df['WindSpeed'],df['AQI'],color='blue')
