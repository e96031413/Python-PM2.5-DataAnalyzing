# %% [markdown]
# ## 高雄1982年至2018年之資料

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
#使用三種不同的資料

#df = pd.read_csv("200811-201811.csv")
df=pd.read_excel('KH-1982-2018.xlsx')
df.isnull().sum()
# Out:
# SO2          0
# CO           0
# O3           0
# PM25         0
# Nox          0
# NO           0
# NO2          0
# THC          0
# NMHC         0
# CH4          0
# WindSpeed    0
# TEMP         0
# Humidity     0
# dtype: int64

# %%
df.head()
# Out:
#    SO2    CO    O3  PM25    Nox    NO    NO2    THC   NMHC   CH4  WindSpeed  \
# 0  5.1  0.57  44.3    29  25.65  3.37  22.28  2.237  0.195  2.04       1.65
# 1  5.0  0.44  43.7    35  17.93  1.76  16.17  2.353  0.176  2.18       1.52
# 2  3.4  0.46  49.6    32  15.56  1.80  13.78  2.129  0.136  1.99       2.27
# 3  3.8  0.53  45.0    30  20.34  1.61  18.72  2.239  0.224  2.02       1.73
# 4  6.7  0.47  43.7    29  24.65  3.49  21.17  2.155  0.186  1.97       1.82
#
#     TEMP  Humidity
# 0  27.01     69.31
# 1  26.17     78.20
# 2  26.18     72.71
# 3  27.35     66.75
# 4  27.80     67.62

# %%
df.corr()
# Out:
#                 SO2        CO        O3      PM25       Nox        NO  \
# SO2        1.000000  0.134392 -0.057634  0.063965  0.340144  0.341898
# CO         0.134392  1.000000  0.088953  0.787843  0.903960  0.624668
# O3        -0.057634  0.088953  1.000000  0.330788 -0.067532 -0.475109
# PM25       0.063965  0.787843  0.330788  1.000000  0.773512  0.366819
# Nox        0.340144  0.903960 -0.067532  0.773512  1.000000  0.794830
# NO         0.341898  0.624668 -0.475109  0.366819  0.794830  1.000000
# NO2        0.314819  0.917078  0.053204  0.832371  0.985037  0.678357
# THC        0.202582  0.791983  0.190791  0.811856  0.755185  0.446833
# NMHC       0.269079  0.888762 -0.122073  0.652208  0.878462  0.748353
# CH4        0.104602  0.526732  0.360650  0.721967  0.480292  0.124298
# WindSpeed -0.216992 -0.397686  0.177779 -0.019018 -0.321410 -0.368937
# TEMP       0.031893 -0.727473 -0.118516 -0.874027 -0.748773 -0.464419
# Humidity  -0.039388 -0.359540 -0.204880 -0.398290 -0.312727 -0.056082
#
#                 NO2       THC      NMHC       CH4  WindSpeed      TEMP  \
# SO2        0.314819  0.202582  0.269079  0.104602  -0.216992  0.031893
# CO         0.917078  0.791983  0.888762  0.526732  -0.397686 -0.727473
# O3         0.053204  0.190791 -0.122073  0.360650   0.177779 -0.118516
# PM25       0.832371  0.811856  0.652208  0.721967  -0.019018 -0.874027
# Nox        0.985037  0.755185  0.878462  0.480292  -0.321410 -0.748773
# NO         0.678357  0.446833  0.748353  0.124298  -0.368937 -0.464419
# NO2        1.000000  0.787432  0.851076  0.546191  -0.284397 -0.774693
# THC        0.787432  1.000000  0.786889  0.900609  -0.281139 -0.723027
# NMHC       0.851076  0.786889  1.000000  0.441037  -0.516237 -0.583771
# CH4        0.546191  0.900609  0.441037  1.000000  -0.046393 -0.640429
# WindSpeed -0.284397 -0.281139 -0.516237 -0.046393   1.000000 -0.096096
# TEMP      -0.774693 -0.723027 -0.583771 -0.640429  -0.096096  1.000000
# Humidity  -0.362807 -0.216910 -0.247499 -0.139867   0.093450  0.323735
#
#            Humidity
# SO2       -0.039388
# CO        -0.359540
# O3        -0.204880
# PM25      -0.398290
# Nox       -0.312727
# NO        -0.056082
# NO2       -0.362807
# THC       -0.216910
# NMHC      -0.247499
# CH4       -0.139867
# WindSpeed  0.093450
# TEMP       0.323735
# Humidity   1.000000

# %%
ax=df.plot(kind='scatter',x='TEMP',y="PM25")
ax.set_title('TEMP v.s. PM25')
# Out:
# Text(0.5,1,'TEMP v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='Humidity',y="PM25")
ax.set_title('Humidity v.s. PM25')
# Out:
# Text(0.5,1,'Humidity v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='WindSpeed',y="PM25")
ax.set_title('WindSpeed v.s. PM25')
# Out:
# Text(0.5,1,'WindSpeed v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='CH4',y="PM25")
ax.set_title('CH4 v.s. PM25')
# Out:
# Text(0.5,1,'CH4 v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='NMHC',y="PM25")
ax.set_title('NMHC v.s. PM25')
# Out:
# Text(0.5,1,'NMHC v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='THC',y="PM25")
ax.set_title('THC v.s. PM25')
# Out:
# Text(0.5,1,'THC v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='NO2',y="PM25")
ax.set_title('NO2 v.s. PM25')
# Out:
# Text(0.5,1,'NO2 v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='NO',y="PM25")
ax.set_title('NO v.s. PM25')
# Out:
# Text(0.5,1,'NO v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='Nox',y="PM25")
ax.set_title('Nox v.s. PM25')
# Out:
# Text(0.5,1,'Nox v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='PM25',y="PM25")
ax.set_title('PM25 v.s. PM25')
# Out:
# Text(0.5,1,'PM25 v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='O3',y="PM25")
ax.set_title('O3 v.s. PM25')
# Out:
# Text(0.5,1,'O3 v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='CO',y="PM25")
ax.set_title('CO v.s. PM25')
# Out:
# Text(0.5,1,'CO v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='SO2',y="PM25")
ax.set_title('SO2 v.s. PM25')
# Out:
# Text(0.5,1,'SO2 v.s. PM25')

# %%
heatmap = df.corr()
sns.heatmap(heatmap,cmap='coolwarm')
