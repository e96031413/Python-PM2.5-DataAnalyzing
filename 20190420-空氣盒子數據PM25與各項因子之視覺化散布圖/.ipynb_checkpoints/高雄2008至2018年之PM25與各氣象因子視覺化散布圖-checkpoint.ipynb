# %% [markdown]
# ## 高雄2008年至2018年之資料

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("200811-201811.csv")
df.isnull().sum()
# Out:
# SO2          0
# CO           0
# O3           0
# PM25         0
# Nox          0
# NO           0
# NO2          0
# THC          0
# NMHC         0
# CH4          0
# WindSpeed    0
# TEMP         0
# Humidity     0
# dtype: int64

# %%
df.head()
# Out:
#    SO2    CO    O3  PM25  Nox    NO    NO2    THC   NMHC    CH4  WindSpeed  \
# 0  4.4  0.47  32.2    31   24  3.46  20.84  2.309  0.231  2.078       1.91
# 1  6.4  0.52  30.2    32   32  5.64  26.30  2.186  0.227  1.959       1.72
# 2  3.2  0.45  30.5    46   20  2.36  18.05  0.000  0.000  0.000       2.08
# 3  5.2  0.47  32.5    38   24  3.18  20.64  2.374  0.225  2.150       1.66
# 4  4.5  0.72  29.9    32   29  5.43  23.82  2.290  0.287  2.004       1.03
#
#     TEMP  Humidity
# 0  24.86     77.11
# 1  26.58     71.93
# 2  24.75     76.33
# 3  24.97     79.97
# 4  26.18     73.78

# %%
df.corr()
# Out:
#                 SO2        CO        O3      PM25       Nox        NO  \
# SO2        1.000000  0.303866 -0.024698  0.188136  0.524684  0.472177
# CO         0.303866  1.000000  0.092858  0.795038  0.894954  0.642657
# O3        -0.024698  0.092858  1.000000  0.352136 -0.080621 -0.458057
# PM25       0.188136  0.795038  0.352136  1.000000  0.730193  0.364917
# Nox        0.524684  0.894954 -0.080621  0.730193  1.000000  0.820732
# NO         0.472177  0.642657 -0.458057  0.364917  0.820732  1.000000
# NO2        0.508340  0.909704  0.026889  0.785542  0.987236  0.722519
# THC        0.117229  0.072982  0.001201 -0.019239  0.146844  0.101917
# NMHC       0.191428  0.381906 -0.062447  0.195218  0.428441  0.367894
# CH4        0.107417  0.038460  0.008016 -0.042134  0.114175  0.071649
# WindSpeed -0.031574 -0.260635  0.070815 -0.035068 -0.110563 -0.175977
# TEMP      -0.034631 -0.706422 -0.115812 -0.857261 -0.662741 -0.408278
# Humidity  -0.136528 -0.446872 -0.246962 -0.481908 -0.371383 -0.134137
#
#                 NO2       THC      NMHC       CH4  WindSpeed      TEMP  \
# SO2        0.508340  0.117229  0.191428  0.107417  -0.031574 -0.034631
# CO         0.909704  0.072982  0.381906  0.038460  -0.260635 -0.706422
# O3         0.026889  0.001201 -0.062447  0.008016   0.070815 -0.115812
# PM25       0.785542 -0.019239  0.195218 -0.042134  -0.035068 -0.857261
# Nox        0.987236  0.146844  0.428441  0.114175  -0.110563 -0.662741
# NO         0.722519  0.101917  0.367894  0.071649  -0.175977 -0.408278
# NO2        1.000000  0.153022  0.421335  0.121688  -0.085335 -0.693387
# THC        0.153022  1.000000  0.873964  0.998616   0.044608  0.055535
# NMHC       0.421335  0.873964  1.000000  0.847199  -0.147782 -0.147060
# CH4        0.121688  0.998616  0.847199  1.000000   0.064774  0.076592
# WindSpeed -0.085335  0.044608 -0.147782  0.064774   1.000000 -0.044955
# TEMP      -0.693387  0.055535 -0.147060  0.076592  -0.044955  1.000000
# Humidity  -0.415924  0.078777 -0.023365  0.088684   0.063429  0.395512
#
#            Humidity
# SO2       -0.136528
# CO        -0.446872
# O3        -0.246962
# PM25      -0.481908
# Nox       -0.371383
# NO        -0.134137
# NO2       -0.415924
# THC        0.078777
# NMHC      -0.023365
# CH4        0.088684
# WindSpeed  0.063429
# TEMP       0.395512
# Humidity   1.000000

# %%
ax=df.plot(kind='scatter',x='TEMP',y="PM25")
ax.set_title('TEMP v.s. PM25')
# Out:
# Text(0.5,1,'TEMP v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='Humidity',y="PM25")
ax.set_title('Humidity v.s. PM25')
# Out:
# Text(0.5,1,'Humidity v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='WindSpeed',y="PM25")
ax.set_title('WindSpeed v.s. PM25')
# Out:
# Text(0.5,1,'WindSpeed v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='CH4',y="PM25")
ax.set_title('CH4 v.s. PM25')
# Out:
# Text(0.5,1,'CH4 v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='NMHC',y="PM25")
ax.set_title('NMHC v.s. PM25')
# Out:
# Text(0.5,1,'NMHC v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='THC',y="PM25")
ax.set_title('THC v.s. PM25')
# Out:
# Text(0.5,1,'THC v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='NO2',y="PM25")
ax.set_title('NO2 v.s. PM25')
# Out:
# Text(0.5,1,'NO2 v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='NO',y="PM25")
ax.set_title('NO v.s. PM25')
# Out:
# Text(0.5,1,'NO v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='Nox',y="PM25")
ax.set_title('Nox v.s. PM25')
# Out:
# Text(0.5,1,'Nox v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='PM25',y="PM25")
ax.set_title('PM25 v.s. PM25')
# Out:
# Text(0.5,1,'PM25 v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='O3',y="PM25")
ax.set_title('O3 v.s. PM25')
# Out:
# Text(0.5,1,'O3 v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='CO',y="PM25")
ax.set_title('CO v.s. PM25')
# Out:
# Text(0.5,1,'CO v.s. PM25')

# %%
ax=df.plot(kind='scatter',x='SO2',y="PM25")
ax.set_title('SO2 v.s. PM25')
# Out:
# Text(0.5,1,'SO2 v.s. PM25')

# %%
heatmap = df.corr()
sns.heatmap(heatmap,cmap='coolwarm')
