# %%
import pandas as pd
df=pd.read_csv('C:/Users/Yanwei/Desktop/AQI.csv')

# %%
df.head()
# Out:
#   SiteName County    AQI Pollutant    Status  SO2    CO  CO_8hr  O3  O3_8hr  \
# 0       麥寮    雲林縣  160.0      懸浮微粒   對所有族群不良  2.6  0.41     0.5  45    28.0
# 1       崙背    雲林縣  109.0      懸浮微粒  對敏感族群不健康  2.0   0.4     0.4  45    28.0
# 2      富貴角    新北市   57.0     細懸浮微粒        普通  0.1  0.28     0.3  46    37.0
# 3       麥寮    雲林縣  160.0      懸浮微粒  對所有族群不健康  2.6  0.41     0.5  45    28.0
# 4       關山    臺東縣   32.0       NaN        良好  1.9     -     NaN  28    20.0
#
#      ...      NO2   NOx   NO  WindSpeed  WindDirec       PublishTime  \
# 0    ...      8.5  10.0  1.5        8.7        1.7  2018-11-22 13:00
# 1    ...      8.6  11.0  2.8        3.9        9.7  2018-11-22 13:00
# 2    ...      2.8   2.8  0.0        9.7       32.0  2018-11-22 13:00
# 3    ...      8.5  10.0  1.5        8.7        1.7  2018-11-22 13:00
# 4    ...      5.2   7.6  2.4        2.4      108.0  2018-11-22 13:00
#
#    PM2.5_AVG PM10_AVG   Longitude   Latitude
# 0         22    273.0  120.251825  23.753506
# ...

# %%
len(df)
# Out:
# 78

# %%
df.describe()
# Out:
#               AQI        SO2     CO_8hr     O3_8hr        PM10        NO2  \
# count   77.000000  77.000000  77.000000  76.000000   76.000000  77.000000
# mean    62.597403   2.119481   0.523377  26.921053   64.447368  12.174026
# std     39.014930   0.923244   0.224133   6.181183   65.798560   7.340253
# min     20.000000   0.100000   0.300000   7.000000    5.000000   1.700000
# 25%     32.000000   1.600000   0.400000  23.750000   27.750000   7.600000
# 50%     47.000000   2.000000   0.500000  28.000000   37.500000  11.000000
# 75%     88.000000   2.600000   0.600000  31.000000   75.500000  17.000000
# max    160.000000   6.000000   1.900000  39.000000  300.000000  42.000000
#
#               NOx         NO  WindSpeed   WindDirec  PM2.5_AVG    PM10_AVG  \
# count   77.000000  77.000000  74.000000   74.000000  78.000000   77.000000
# mean    15.672727   3.611688   4.214865  122.800000  18.141026   52.610390
# std     14.886674   9.240300   2.883048  125.234351  12.759233   51.940795
# ...

# %%
df['AQI']
df[(df.AQI < 30)&(df.WindSpeed>2)]
# Out:
#    SiteName County   AQI Pollutant Status  SO2    CO  CO_8hr  O3  O3_8hr  \
# 14       冬山    宜蘭縣  22.0       NaN     良好  1.1  0.34     0.5  37    24.0
# 17       花蓮    花蓮縣  29.0       NaN     良好  1.4  0.39     0.4  38    31.0
# 18       臺東    臺東縣  27.0       NaN     良好  1.0  0.45     0.4  30    25.0
# 48       大里    臺中市  24.0       NaN     良好  1.9   0.5     0.5  38    25.0
# 49       沙鹿    臺中市  28.0       NaN     良好  1.5  0.38     0.4  42    30.0
# 60       大園    桃園市  28.0       NaN     良好  2.4  0.34     0.4  42    30.0
# 61       桃園    桃園市  22.0       NaN     良好  2.3  0.46     0.5  32    24.0
# 69       林口    新北市  26.0       NaN     良好  1.1  0.34     0.4  35    28.0
# 76       汐止    新北市  27.0       NaN     良好  1.6   0.4     0.4  34    29.0
#
#       ...       NO2   NOx   NO  WindSpeed  WindDirec       PublishTime  \
# 14    ...       6.4   8.5  2.1        2.1      246.0  2018-11-22 13:00
# 17    ...       6.6   7.2  0.6        3.7       55.0  2018-11-22 13:00
# ...

# %%
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']    # 指定默认字体：解决plot不能显示中文问题
mpl.rcParams['axes.unicode_minus'] = False 
df.plot(x='SiteName', y=['AQI'])

# %%
df['AQI']
# Out:
# 0     160.0
# 1     109.0
# 2      57.0
# 3     160.0
# 4      32.0
# 5      42.0
# 6      35.0
# 7      47.0
# 8      67.0
# 9     116.0
# 10     27.0
# 11     67.0
# 12     26.0
# 13     40.0
# 14     22.0
# 15     35.0
# 16     32.0
# 17     29.0
# 18     27.0
# 19     36.0
# 20    121.0
# 21    138.0
# 22    108.0
# 23    113.0
# 24    131.0
# 25     90.0
# 26    104.0
# 27    152.0
# 28    144.0
# 29    119.0
#       ...
# 48     24.0
# 49     28.0
# 50     35.0
# 51     40.0
# 52     47.0
# 53     44.0
# 54     52.0
# 55     34.0
# 56     30.0
# 57     54.0
# 58     52.0
# 59     55.0
# 60     28.0
# 61     22.0
# 62      NaN
# 63     20.0
# 64     38.0
# 65     25.0
# 66     26.0
# 67     36.0
# 68     32.0
# 69     26.0
# 70     28.0
# 71     30.0
# 72     44.0
# 73     48.0
# 74     43.0
# 75     49.0
# 76     27.0
# 77     30.0
# Name: AQI, Length: 78, dtype: float64

# %%
df.sort_index(ascending=True).head()
# Out:
#   SiteName County    AQI Pollutant    Status  SO2    CO  CO_8hr  O3  O3_8hr  \
# 0       麥寮    雲林縣  160.0      懸浮微粒   對所有族群不良  2.6  0.41     0.5  45    28.0
# 1       崙背    雲林縣  109.0      懸浮微粒  對敏感族群不健康  2.0   0.4     0.4  45    28.0
# 2      富貴角    新北市   57.0     細懸浮微粒        普通  0.1  0.28     0.3  46    37.0
# 3       麥寮    雲林縣  160.0      懸浮微粒  對所有族群不健康  2.6  0.41     0.5  45    28.0
# 4       關山    臺東縣   32.0       NaN        良好  1.9     -     NaN  28    20.0
#
#      ...      NO2   NOx   NO  WindSpeed  WindDirec       PublishTime  \
# 0    ...      8.5  10.0  1.5        8.7        1.7  2018-11-22 13:00
# 1    ...      8.6  11.0  2.8        3.9        9.7  2018-11-22 13:00
# 2    ...      2.8   2.8  0.0        9.7       32.0  2018-11-22 13:00
# 3    ...      8.5  10.0  1.5        8.7        1.7  2018-11-22 13:00
# 4    ...      5.2   7.6  2.4        2.4      108.0  2018-11-22 13:00
#
#    PM2.5_AVG PM10_AVG   Longitude   Latitude
# 0         22    273.0  120.251825  23.753506
# ...

# %%
df.sort_index(ascending=False).head()
# Out:
#    SiteName County   AQI Pollutant Status  SO2    CO  CO_8hr  O3  O3_8hr  \
# 77       基隆    基隆市  30.0       NaN     良好  1.3  0.32     0.4  41    32.0
# 76       汐止    新北市  27.0       NaN     良好  1.6   0.4     0.4  34    29.0
# 75       萬里    新北市  49.0       NaN     良好  2.4  0.29     0.3  48    39.0
# 74       新店    新北市  43.0       NaN     良好  1.6  0.31     0.5  32    21.0
# 73       土城    新北市  48.0       NaN     良好  2.4  0.49     0.6  24    16.0
#
#       ...       NO2   NOx   NO  WindSpeed  WindDirec       PublishTime  \
# 77    ...       5.4   6.6  1.2        2.0       85.0  2018-11-22 13:00
# 76    ...      16.0  18.0  2.2        2.1       59.0  2018-11-22 13:00
# 75    ...       2.8   4.2  1.3       11.0       21.0  2018-11-22 13:00
# 74    ...      12.0  15.0  3.0        2.2      128.0  2018-11-22 13:00
# 73    ...      21.0  24.0  2.6        1.4      158.0  2018-11-22 13:00
#
#     PM2.5_AVG PM10_AVG   Longitude   Latitude
# 77          9     28.0  121.760056  25.129167
# ...

# %%
df.shape
# Out:
# (78, 22)

# %%
df.mean()
# Out:
# AQI           62.597403
# SO2            2.119481
# CO_8hr         0.523377
# O3_8hr        26.921053
# PM10          64.447368
# NO2           12.174026
# NOx           15.672727
# NO             3.611688
# WindSpeed      4.214865
# WindDirec    122.800000
# PM2.5_AVG     18.141026
# PM10_AVG      52.610390
# Longitude    120.838019
# Latitude      24.078813
# dtype: float64

# %%
AQI_filter = df['AQI']>60
YYY=df[AQI_filter]
YYY.head()
# Out:
#   SiteName County    AQI Pollutant    Status  SO2    CO  CO_8hr  O3  O3_8hr  \
# 0       麥寮    雲林縣  160.0      懸浮微粒   對所有族群不良  2.6  0.41     0.5  45    28.0
# 1       崙背    雲林縣  109.0      懸浮微粒  對敏感族群不健康  2.0   0.4     0.4  45    28.0
# 3       麥寮    雲林縣  160.0      懸浮微粒  對所有族群不健康  2.6  0.41     0.5  45    28.0
# 8       埔里    南投縣   67.0     細懸浮微粒        普通  0.9  0.31     0.5  48    24.0
# 9       復興    高雄市  116.0     細懸浮微粒  對敏感族群不健康  2.9  0.71     0.8  62    26.0
#
#      ...       NO2   NOx   NO  WindSpeed  WindDirec       PublishTime  \
# 0    ...       8.5  10.0  1.5        8.7        1.7  2018-11-22 13:00
# 1    ...       8.6  11.0  2.8        3.9        9.7  2018-11-22 13:00
# 3    ...       8.5  10.0  1.5        8.7        1.7  2018-11-22 13:00
# 8    ...       7.8   8.7  0.8        3.1      288.0  2018-11-22 13:00
# 9    ...      18.0  21.0  2.6        1.6      278.0  2018-11-22 13:00
#
#    PM2.5_AVG PM10_AVG   Longitude   Latitude
# ...

# %%
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']    # 指定默认字体：解决plot不能显示中文问题
mpl.rcParams['axes.unicode_minus'] = False 
pic=df.plot(kind = 'scatter', x = 'PM10', y = 'AQI', title = 'PM10指數與AQI之關係')
print(pic)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df.corr()
# Out:
#                 AQI       SO2    CO_8hr    O3_8hr      PM10       NO2  \
# AQI        1.000000  0.538016  0.001224  0.259126  0.720179  0.035422
# SO2        0.538016  1.000000  0.236950  0.045333  0.292581  0.438428
# CO_8hr     0.001224  0.236950  1.000000 -0.613176 -0.066419  0.763664
# O3_8hr     0.259126  0.045333 -0.613176  1.000000  0.289111 -0.599267
# PM10       0.720179  0.292581 -0.066419  0.289111  1.000000 -0.100259
# NO2        0.035422  0.438428  0.763664 -0.599267 -0.100259  1.000000
# NOx       -0.037921  0.318923  0.911375 -0.622106 -0.086582  0.870123
# NO        -0.096203  0.166291  0.865408 -0.548107 -0.059431  0.614410
# WindSpeed  0.067097 -0.102904 -0.559318  0.561954  0.344638 -0.543868
# WindDirec  0.228797  0.203133  0.327591 -0.135697 -0.126271  0.219328
# PM2.5_AVG  0.863905  0.592353  0.016298  0.154446  0.316426  0.138305
# PM10_AVG   0.793616  0.316197 -0.049868  0.274660  0.972607 -0.100984
# ...
