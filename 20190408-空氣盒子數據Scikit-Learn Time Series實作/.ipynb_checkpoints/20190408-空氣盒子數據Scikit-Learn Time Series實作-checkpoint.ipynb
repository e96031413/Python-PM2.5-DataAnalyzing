# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_excel('TimeSeries_198211-201811.xlsx')
df.head()
# Out:
#         Date   SO2    CO    O3  PM10  PM25    Nox     NO    NO2    THC  NMHC  \
# 0 1983-10-01  52.1  0.00   0.0   251     0  38.35  10.65  27.38  0.000   0.0
# 1 1983-10-01  45.9  1.66   8.2   119     0  45.65  24.66  21.35  0.000   0.0
# 2 1983-11-01  49.3  0.00   0.0     0     0  48.27  14.52  33.14  0.000   0.0
# 3 1983-11-01   0.0  1.52  10.3   141     0  33.60  16.69  16.75  0.000   0.0
# 4 1983-11-01  36.7  3.82  15.0    88     0  61.57  30.69  38.32  2.087   0.0
#
#     CH4  WindSpeed  TEMP  Humidity
# 0  0.00        0.0   0.0     88.98
# 1  0.00        0.0   0.0     89.84
# 2  0.00        0.0   0.0     76.49
# 3  0.00        0.0   0.0     72.65
# 4  1.74        0.0   0.0     70.07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4036 entries, 0 to 4035
# Data columns (total 15 columns):
# Date         4036 non-null datetime64[ns]
# SO2          4036 non-null float64
# CO           4036 non-null float64
# O3           4036 non-null float64
# PM10         4036 non-null int64
# PM25         4036 non-null int64
# Nox          4036 non-null float64
# NO           4036 non-null float64
# NO2          4036 non-null float64
# THC          4036 non-null float64
# NMHC         4036 non-null float64
# CH4          4036 non-null float64
# WindSpeed    4036 non-null float64
# TEMP         4036 non-null float64
# Humidity     4036 non-null float64
# dtypes: datetime64[ns](1), float64(12), int64(2)
# memory usage: 473.0 KB

# %%
df.Date = pd.to_datetime(df.Date)
df.set_index('Date', inplace=True)

# %%
df.head(5)
# Out:
#              SO2    CO    O3  PM10  PM25    Nox     NO    NO2    THC  NMHC  \
# Date
# 1983-10-01  52.1  0.00   0.0   251     0  38.35  10.65  27.38  0.000   0.0
# 1983-10-01  45.9  1.66   8.2   119     0  45.65  24.66  21.35  0.000   0.0
# 1983-11-01  49.3  0.00   0.0     0     0  48.27  14.52  33.14  0.000   0.0
# 1983-11-01   0.0  1.52  10.3   141     0  33.60  16.69  16.75  0.000   0.0
# 1983-11-01  36.7  3.82  15.0    88     0  61.57  30.69  38.32  2.087   0.0
#
#              CH4  WindSpeed  TEMP  Humidity
# Date
# 1983-10-01  0.00        0.0   0.0     88.98
# 1983-10-01  0.00        0.0   0.0     89.84
# 1983-11-01  0.00        0.0   0.0     76.49
# 1983-11-01  0.00        0.0   0.0     72.65
# 1983-11-01  1.74        0.0   0.0     70.07

# %%
df[['CH4']].plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.title("CH4", fontsize=40)
# Out:
# Text(0.5, 1.0, 'CH4')

# %%
PM25 = df[['PM25']]
PM25.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.title("PM2.5", fontsize=40)
# Out:
# Text(0.5, 1.0, 'PM2.5')

# %%
O3 = df[['O3']]
O3.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.title("O3", fontsize=40)
# Out:
# Text(0.5, 1.0, 'O3')

# %%
CO = df[['CO']]
CO.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.title("CO", fontsize=40)
# Out:
# Text(0.5, 1.0, 'CO')

# %%
CH4 = df[['CH4']]
CH4.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.title("CH4", fontsize=40)
# Out:
# Text(0.5, 1.0, 'CH4')

# %%
df_rm = pd.concat([PM25.rolling(12).mean(), O3.rolling(12).mean(),CO.rolling(12).mean(),CH4.rolling(12).mean()], axis=1)
df_rm.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
