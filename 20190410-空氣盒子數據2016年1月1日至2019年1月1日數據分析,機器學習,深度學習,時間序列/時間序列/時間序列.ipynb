# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_excel('20160101-20190101(Daily).xlsx')
df.head()
# Out:
#         Date Location  SO2    CO    O3  PM10  PM25  Nox    NO    NO2   THC  \
# 0 2016-01-01       左營  4.8  0.69  35.6   111    71   29  4.07  24.54  2.30
# 1 2016-01-01       楠梓  4.0  0.65  33.0   130    62   26  5.01  21.46  2.20
# 2 2016-01-01       前金  5.6  0.72  37.0   129    69   28  4.00  23.71  2.26
# 3 2016-01-01       前鎮  5.4  0.95  31.7   107    58   38  6.71  31.37  2.40
# 4 2016-01-01       復興  0.0  0.00   0.0     0    68    0  0.00   0.00  0.00
#
#     NMHC    CH4  WindSpeed   TEMP  Humidity
# 0  0.208  2.087       2.00  19.45     75.11
# 1  0.198  1.999       2.12  19.44     73.19
# 2  0.218  2.045       2.28  19.86     69.26
# 3  0.302  2.100       1.65  20.29     68.40
# 4  0.000  0.000       0.00   0.00      0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15188 entries, 0 to 15187
# Data columns (total 16 columns):
# Date         15188 non-null datetime64[ns]
# Location     15188 non-null object
# SO2          15188 non-null float64
# CO           15188 non-null float64
# O3           15188 non-null float64
# PM10         15188 non-null int64
# PM25         15188 non-null int64
# Nox          15188 non-null int64
# NO           15188 non-null float64
# NO2          15188 non-null float64
# THC          15188 non-null float64
# NMHC         15188 non-null float64
# CH4          15188 non-null float64
# WindSpeed    15188 non-null float64
# TEMP         15188 non-null float64
# Humidity     15188 non-null float64
# dtypes: datetime64[ns](1), float64(11), int64(3), object(1)
# memory usage: 1.9+ MB

# %%
df.Date = pd.to_datetime(df.Date)
df.set_index('Date', inplace=True)

# %%
df.head(5)
# Out:
#            Location  SO2    CO    O3  PM10  PM25  Nox    NO    NO2   THC  \
# Date
# 2016-01-01       左營  4.8  0.69  35.6   111    71   29  4.07  24.54  2.30
# 2016-01-01       楠梓  4.0  0.65  33.0   130    62   26  5.01  21.46  2.20
# 2016-01-01       前金  5.6  0.72  37.0   129    69   28  4.00  23.71  2.26
# 2016-01-01       前鎮  5.4  0.95  31.7   107    58   38  6.71  31.37  2.40
# 2016-01-01       復興  0.0  0.00   0.0     0    68    0  0.00   0.00  0.00
#
#              NMHC    CH4  WindSpeed   TEMP  Humidity
# Date
# 2016-01-01  0.208  2.087       2.00  19.45     75.11
# 2016-01-01  0.198  1.999       2.12  19.44     73.19
# 2016-01-01  0.218  2.045       2.28  19.86     69.26
# 2016-01-01  0.302  2.100       1.65  20.29     68.40
# 2016-01-01  0.000  0.000       0.00   0.00      0.00

# %%
CH4 = df[['CH4']]
CH4.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.title("PM2.5", fontsize=40)
# Out:
# Text(0.5, 1.0, 'PM2.5')

# %%
PM25 = df[['PM25']]
PM25.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.title("PM2.5", fontsize=40)
# Out:
# Text(0.5, 1.0, 'PM2.5')

# %%
O3 = df[['O3']]
O3.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.title("O3", fontsize=40)
# Out:
# Text(0.5, 1.0, 'O3')

# %%
CO = df[['CO']]
CO.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.title("CO", fontsize=40)
# Out:
# Text(0.5, 1.0, 'CO')

# %%
CH4 = df[['CH4']]
CH4.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.title("CH4", fontsize=40)
# Out:
# Text(0.5, 1.0, 'CH4')

# %%
df_rm = pd.concat([PM25.rolling(12).mean(), O3.rolling(12).mean(),CO.rolling(12).mean(),CH4.rolling(12).mean()], axis=1)
df_rm.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
