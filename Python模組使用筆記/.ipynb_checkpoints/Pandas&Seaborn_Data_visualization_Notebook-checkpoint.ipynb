# %% [markdown]
# # Pandas繪圖筆記

# %% [markdown]
# ### 有以下7種類型的圖###
# + 折線圖df.plot()
# + 柱狀圖df.plot(kind='bar')
# + 橫向柱狀圖df.plot(kind='barh')
# + 直方圖df.plot(kind='hist')
# + KDE圖df.plot(kind='kde')
# + 面積圖df.plot(kind='area')
# + 圓餅圖df.plot(kind='pie')
# + 散佈圖df.plot(kind='scatter')
# + 六角形箱體圖df.plot(kind='hexbin')
# + 箱形圖df.plot(kind='box')

# %% [markdown]
# ## 1.初始化

# %%
import pandas as pd #引入Pandas模組 as pd
import seaborn as sns #引入seaborn模組 as sns
# %matplotlib inline
pd.set_option("display.max_rows", 1000)    #設定最大能顯示1000rows
pd.set_option("display.max_columns", 1000) #設定最大能顯示1000columns

# %% [markdown]
# ## 2.解決plot不能顯示中文問題

# %%
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']  
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 3.讀取檔案

# %%
df=pd.read_excel('C:/Users/Yanwei/a.xlsx')

# %% [markdown]
# ## 4.資料操作

# %% [markdown]
# ### 4.1NaN與重複值處理

# %%
df=df.dropna()
df=df.drop_duplicates()

# %%
df.head(30)
# Out:
#          監測日期  測站  SO2    CO    O3  PM10  PM25  Nox    NO    NO2   THC   NMHC  \
# 0  2018-11-01  楠梓  3.4  0.53  35.2    75    50   27  6.20  21.14  2.23  0.245
# 1  2018-11-02  楠梓  3.7  0.49  24.2    74    44   31  7.08  24.41  2.30  0.307
# 2  2018-11-03  楠梓  2.5  0.41  12.4    50    34   27  4.52  22.57  2.21  0.239
# 3  2018-11-04  楠梓  2.9  0.40  21.6    54    34   26  5.58  20.49  2.17  0.227
# 4  2018-11-05  楠梓  2.1  0.27  21.6    25    14   17  2.65  14.77  1.97  0.100
# 5  2018-11-06  楠梓  2.5  0.36  40.6    47    30   15  2.47  12.06  2.14  0.191
# 6  2018-11-07  楠梓  2.9  0.49  37.7    61    38   21  2.22  18.52  2.18  0.210
# 7  2018-11-08  楠梓  3.5  0.44  28.7    65    31   23  3.13  19.78  2.14  0.170
# 8  2018-11-09  楠梓  2.7  0.56  34.1    85    39   20  2.81  17.42  2.19  0.181
# 9  2018-11-10  楠梓  3.3  0.49  41.3    63    34   23  3.25  19.47  2.21  0.230
# 10 2018-11-11  楠梓  4.0  0.47  30.4    54    25   26  5.40  20.14  2.25  0.269
# 11 2018-11-12  楠梓  2.5  0.35  23.7    64    26   16  1.99  13.97  2.06  0.123
# 12 2018-11-13  楠梓  4.2  0.53  40.4    62    43   19  3.16  16.01  2.16  0.174
# 13 2018-11-14  楠梓  3.6  0.57  35.1    94    60   22  2.56  19.73  2.30  0.237
# 14 2018-11-15  楠梓  3.2  0.49  42.8    94    57   23  3.54  19.28  2.22  0.216
# 15 2018-11-16  楠梓  3.0  0.53  32.4    73    38   26  5.54  20.63  2.26  0.285
# 16 2018-11-17  楠梓  3.9  0.48  45.8    78    45   20  3.64  16.33  2.15  0.173
# 17 2018-11-18  楠梓  2.3  0.46  35.1    84    47   20  3.61  16.81  2.22  0.230
# 18 2018-11-19  楠梓  2.5  0.44  34.0    95    61   19  2.16  16.73  2.15  0.148
# 19 2018-11-20  楠梓  2.7  0.41  41.3    87    45   15  2.39  12.74  2.04  0.120
# 20 2018-11-21  楠梓  2.9  0.50  32.0    84    34   17  2.38  14.87  2.11  0.162
# 21 2018-11-22  楠梓  3.3  0.43  38.2   106    50   19  2.93  15.84  2.09  0.165
# 22 2018-11-23  楠梓  3.3  0.48  31.3   113    62   22  3.81  18.56  2.42  0.441
# 23 2018-11-24  楠梓  2.9  0.49  37.8   118    57   24  4.23  20.06  2.23  0.239
# 24 2018-11-25  楠梓  3.0  0.45  25.6    90    38   23  3.49  19.94  2.38  0.410
# 25 2018-11-26  楠梓  2.8  0.42  30.3    98    38   20  4.34  16.11  2.20  0.168
# 26 2018-11-27  楠梓  2.4  0.37  26.9    95    48   13  2.48  10.86  2.11  0.164
# 27 2018-11-28  楠梓  2.5  0.41  25.7    62    29   20  6.59  13.12  2.16  0.153
# 28 2018-11-29  楠梓  3.1  0.50  13.7    71    32   30  6.42  23.63  2.26  0.253
# 29 2018-11-30  楠梓  2.3  0.40  17.4    58    27   22  3.76  18.32  2.13  0.156
#
#       CH4    WS   TEMP  Humidity
# 0   1.988  1.76  23.86     76.08
# 1   1.995  1.79  23.11     77.29
# 2   1.967  2.00  22.84     81.49
# 3   1.940  1.81  23.45     76.63
# 4   1.864  2.60  21.13     77.82
# 5   1.946  1.99  23.55     72.03
# 6   1.969  1.59  22.65     75.60
# 7   1.973  2.34  22.46     70.93
# 8   2.013  2.75  23.35     74.16
# 9   1.978  2.12  24.94     76.69
# 10  1.983  1.99  24.33     74.50
# 11  1.938  2.87  25.18     76.30
# 12  1.980  1.73  25.80     78.67
# 13  2.059  1.82  26.09     77.77
# 14  2.006  1.63  26.21     73.95
# 15  1.975  1.59  24.97     74.89
# 16  1.974  1.84  24.44     74.95
# 17  1.992  2.05  24.83     76.19
# 18  2.003  1.83  25.18     77.71
# 19  1.921  1.55  25.59     78.15
# 20  1.952  1.96  25.13     80.01
# 21  1.926  1.98  26.27     77.98
# 22  1.981  1.68  26.15     80.78
# 23  1.995  1.28  26.25     79.83
# 24  1.970  1.14  26.15     79.68
# 25  2.030  1.70  26.00     81.19
# 26  1.950  1.75  25.24     84.67
# 27  2.004  1.52  25.36     80.63
# 28  2.005  1.50  22.40     85.73
# 29  1.974  2.56  21.91     82.98

# %% [markdown]
# ### 4.2檢視資料類型(有無非數值類型存在)

# %%
df.dtypes
# Out:
# 監測日期        datetime64[ns]
# 測站                  object
# SO2                float64
# CO                 float64
# O3                 float64
# PM10                 int64
# PM25                 int64
# Nox                  int64
# NO                 float64
# NO2                float64
# THC                float64
# NMHC               float64
# CH4                float64
# WS                 float64
# TEMP               float64
# Humidity           float64
# dtype: object

# %% [markdown]
# #### 如果屬性是Object，如何改成數值屬性

# %% [markdown]
# df["屬於Object的欄位"] = pd.to_numeric(df.屬於Object的欄位, errors='coerce')

# %% [markdown]
# ### 4.3相關係數

# %%
df.corr()
# Out:
#                SO2        CO        O3      PM10      PM25       Nox  \
# SO2       1.000000  0.625044  0.375149  0.140711  0.266126  0.416505
# CO        0.625044  1.000000  0.376914  0.420935  0.511374  0.459924
# O3        0.375149  0.376914  1.000000  0.371972  0.488885 -0.354896
# PM10      0.140711  0.420935  0.371972  1.000000  0.829229 -0.071352
# PM25      0.266126  0.511374  0.488885  0.829229  1.000000  0.032930
# Nox       0.416505  0.459924 -0.354896 -0.071352  0.032930  1.000000
# NO        0.258268  0.220034 -0.385650 -0.126007 -0.104651  0.788391
# NO2       0.418404  0.509641 -0.312526 -0.010711  0.108559  0.961041
# THC       0.414124  0.608212 -0.038581  0.391285  0.431626  0.627497
# NMHC      0.350661  0.421507 -0.098318  0.295845  0.318694  0.579173
# CH4       0.330001  0.703985  0.117530  0.434266  0.472598  0.404538
# WS       -0.264317 -0.322743 -0.200980 -0.438450 -0.469863 -0.267625
# TEMP      0.234754  0.287530  0.516818  0.741995  0.629267 -0.259757
# Humidity -0.271583 -0.135522 -0.532481  0.221835  0.048341  0.024958
#
#                 NO       NO2       THC      NMHC       CH4        WS  \
# SO2       0.258268  0.418404  0.414124  0.350661  0.330001 -0.264317
# CO        0.220034  0.509641  0.608212  0.421507  0.703985 -0.322743
# O3       -0.385650 -0.312526 -0.038581 -0.098318  0.117530 -0.200980
# PM10     -0.126007 -0.010711  0.391285  0.295845  0.434266 -0.438450
# PM25     -0.104651  0.108559  0.431626  0.318694  0.472598 -0.469863
# Nox       0.788391  0.961041  0.627497  0.579173  0.404538 -0.267625
# NO        1.000000  0.595347  0.441302  0.399092  0.298337 -0.347144
# NO2       0.595347  1.000000  0.641319  0.598984  0.401096 -0.204648
# THC       0.441302  0.641319  1.000000  0.930130  0.641154 -0.505959
# NMHC      0.399092  0.598984  0.930130  1.000000  0.316099 -0.481961
# CH4       0.298337  0.401096  0.641154  0.316099  1.000000 -0.293489
# WS       -0.347144 -0.204648 -0.505959 -0.481961 -0.293489  1.000000
# TEMP     -0.170636 -0.256691  0.282384  0.208473  0.308056 -0.477085
# Humidity  0.178350 -0.012940  0.089359  0.078501  0.058559 -0.279453
#
#               TEMP  Humidity
# SO2       0.234754 -0.271583
# CO        0.287530 -0.135522
# O3        0.516818 -0.532481
# PM10      0.741995  0.221835
# PM25      0.629267  0.048341
# Nox      -0.259757  0.024958
# NO       -0.170636  0.178350
# NO2      -0.256691 -0.012940
# THC       0.282384  0.089359
# NMHC      0.208473  0.078501
# CH4       0.308056  0.058559
# WS       -0.477085 -0.279453
# TEMP      1.000000  0.084793
# Humidity  0.084793  1.000000

# %% [markdown]
# ## 5.繪圖

# %% [markdown]
# ### 5.1折線圖

# %%
df.plot(x='監測日期', y='PM25',title='監測日期與PM2.5的關係')
df.plot(x='監測日期', y='PM10',title='監測日期與PM10的關係')

# %% [markdown]
# ### 5.2柱狀圖

# %%
df.plot(kind='bar',x='監測日期', y='PM25',title='監測日期與PM2.5的關係')

# %% [markdown]
# ### 5.2.1橫向柱狀圖

# %%
df.plot(kind='barh',x='監測日期', y='PM25',title='監測日期與PM2.5的關係')

# %% [markdown]
# ### 5.3直方圖

# %%
df.plot(kind='hist',x='監測日期', y='PM25',title='監測日期與PM2.5的關係')

# %% [markdown]
# ### 5.4核密度(KDE)圖

# %%
df.plot(kind='kde',x='監測日期', y='PM25',title='監測日期與PM2.5的關係')

# %% [markdown]
# ### 5.5面積圖

# %%
df.plot(kind='area',x='監測日期', y='PM25',title='監測日期與PM2.5的關係')

# %% [markdown]
# ### 5.6圓餅圖

# %%
df.plot(kind='pie',x='監測日期', y='PM25',title='監測日期與PM2.5的關係',autopct = '%1.2f%%')

# %% [markdown]
# ### 5.7散佈圖

# %%
df.plot(kind='scatter',x='PM25', y='PM10',title='PM2.5與PM10的關係') #X,Y需為數值

# %% [markdown]
# ### 5.8六角形箱體圖

# %%
df.plot(kind='hexbin',x='PM25', y='PM10',title='PM2.5與PM10的關係') #X,Y需為數值

# %% [markdown]
# ### 5.9箱形圖

# %%
df.plot(kind='box',x='PM25', y='PM10',title='監測日期與PM2.5的關係') #X,Y需為數值
